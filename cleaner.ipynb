# %%
#Basic imports
from datetime import datetime
from dotenv import load_dotenv
import os
import base64
import hashlib

#Parse text
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET

#Organize 
import openai
from openai import OpenAI

# %%
#Get OpenAI API key
load_dotenv()  
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

# %%
#Function for extracting images from enex file

#Find every resource block in evernote note, decode the base64 data, and save 
def extract_resources(note_elem, output_dir="resources"):
    os.makedirs(output_dir, exist_ok=True)
    resources_map = {}

    for res in note_elem.findall("resource"):
        data_elem = res.find("data")
        mime = res.findtext("mime")

        if data_elem is None or not data_elem.text:
            print("⚠️ Skipping resource with no data")
            continue

        try:
            # Decode the binary data
            binary_data = base64.b64decode(data_elem.text)
        except Exception as e:
            print("⚠️ Error decoding resource:", e)
            continue

        #Compute MD5 digest
        hash_val = hashlib.md5(binary_data).hexdigest()

        #File extension from MIME
        ext = "png" if mime == "image/png" else "jpg" if mime == "image/jpeg" else "bin"
        filename = f"{hash_val}.{ext}"
        filepath = os.path.join(output_dir, filename)

        #Save file
        with open(filepath, "wb") as f:
            f.write(binary_data)

        resources_map[hash_val] = f"{output_dir}/{filename}"

    print("Extracted resources:", list(resources_map.keys())[:5])
    return resources_map

# %%
#Function to replace the tag in the content 

def replace_en_media(content_html, resources_map):
    soup = BeautifulSoup(content_html, "html.parser")
    for media in soup.find_all("en-media"):
        hash_val = media.get("hash")
        if hash_val in resources_map:
            new_img = soup.new_tag("img", src=resources_map[hash_val])
            media.replace_with(new_img)
    return str(soup)

# %%
# Parse the metadata with XML parser
tree = ET.parse("test.enex")
root = tree.getroot()
note_elem = root.find("note")
for child in note_elem:
    print(child.tag, child.text[:50])
# Out:
# title Abdominoplasty and Belt Lipectomy
# created 20180311T201956Z
# updated 20241022T190033Z
# note-attributes
#
# content
#       <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE en-note SYSTEM "http://xml.e
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource
#
# resource

# %%
#Let's peek at things
print(note_elem.find("title").text)
print(note_elem.find("created").text)
print(note_elem.find("updated").text)
# Out:
# Abdominoplasty and Belt Lipectomy
# 20180311T201956Z
# 20241022T190033Z

# %%
#Pull out metadata for YAML file
title = note_elem.find("title").text
created = note_elem.find("created").text
updated = note_elem.find("updated").text
tags = [tag_elem.text for tag_elem in note_elem.findall("tag")]

#Dates need to be converted to ISO for cleaner formatting
created = datetime.strptime(created, "%Y%m%dT%H%M%SZ").isoformat()
updated = datetime.strptime(updated, "%Y%m%dT%H%M%SZ").isoformat()

# %%
#Create YAML string
lines = []
lines.append("---")
lines.append(f"title: \"{title}\"")
lines.append(f"created: {created}")
lines.append(f"updated: {updated}")
if tags:
    lines.append("tags:")
    for tag in tags:
        lines.append(f"  - {tag}")
lines.append("---")

yaml_metadata = "\n".join(lines)

# %%
#We're interested in the content of the note, which we pass to BeautifulSoup to parse the HTML content
note_elem.find("content").text[:300]
# Out:
# '\n      <?xml version="1.0" encoding="UTF-8" standalone="no"?>\n<!DOCTYPE en-note SYSTEM "http://xml.evernote.com/pub/enml2.dtd"><en-note><div><br/></div><div>Abdominoplasty</div><ul><li><div>Anatomy</div></li><ul><li><div>Ab wall</div></li><ul><li><div>Skin</div></li><li><div>SubQ fat (superficial)</'

# %%
#Save the note content
raw_content = note_elem.find("content").text

# %%
#Clean it up
start = raw_content.find("<en-note>")
end = raw_content.find("</en-note>") + len("</en-note>")

cleaned_content = raw_content[start:end]

#Strip whitespace
cleaned_content = cleaned_content.strip()

# %%
#Map images to resources 
resources_map = extract_resources(note_elem, output_dir="resources")
cleaned_content = replace_en_media(cleaned_content, resources_map)
# Out:
# Extracted resources: ['f606a594cbf16b873d12662f98560ca1', '39b3fad5caeb34d57c093985ab4853df', 'a44e7a7f85ae5beb6eb7b7d3942ffada', '1fb1141589b3c98e327622d637d282ce', '6eae52ad273d203e37f9af59f2f2a7a0']

# %%
#Let's use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(cleaned_content, "html.parser")
en_note = soup.find("en-note")
# Out:
# <en-note>
#  <div>
#   <br/>
#  </div>
#  <div>
#   Abdominoplasty
#  </div>
#  <ul>
#   <li>
#    <div>
#     Anatomy
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Ab wall
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Skin
#      </div>
#     </li>
#     <li>
#      <div>
#       SubQ fat (superficial)
#      </div>
#     </li>
#     <li>
#      <div>
#       Scarpa
#      </div>
#     </li>
#     <li>
#      <div>
#       Subscarpal fat
#      </div>
#     </li>
#     <li>
#      <div>
#       Anterior rectus sheath
#      </div>
#     </li>
#     <li>
#      <div>
#       Muscle
#      </div>
#     </li>
#     <li>
#      <div>
#       Posterior rectus sheath
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Four paired muscles
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Rectus abdominis
#      </div>
#     </li>
#     <li>
#      <div>
#       External oblique
#      </div>
#     </li>
#     <li>
#      <div>
#       Internal oblique
#      </div>
#     </li>
#     <li>
#      <div>
#       Transverse abdominis
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Vascular perfusion
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Zone I - mid abdomen, deep superior and deep inferior epigastrics
#      </div>
#     </li>
#     <li>
#      <div>
#       Zone II - lower abdomen, superficial and deep circumflex, external pudendal
#      </div>
#     </li>
#     <li>
#      <div>
#       Zone III - lateral abdomen, intercostal, subcostal, lumbars
#      </div>
#     </li>
#     <li>
#      <img src="resources/0cb88ac5c5fe42f4c40274db3cea69a8.png"/>
#     </li>
#     <li>
#      <div>
#       <br/>
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Prior to abdominoplasty, zone I is major supply, but after, it's zone III
#     </div>
#    </li>
#    <li>
#     <img src="resources/6eae52ad273d203e37f9af59f2f2a7a0.png"/>
#    </li>
#    <li>
#     <div>
#      To avoid lateral femoral cutaneous injury (meralgia paresthetica), dissect superficial when 2cm medial to ASIS
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Patient selection and evaluation
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Medical history - ASA class
#     </div>
#    </li>
#    <li>
#     <div>
#      Parity/gravidity history
#     </div>
#    </li>
#    <li>
#     <div>
#      Previous abdominal surgeries/hernias
#     </div>
#    </li>
#    <li>
#     <div>
#      Weight loss/gain
#     </div>
#    </li>
#    <li>
#     <div>
#      GI or respiratory ailments
#     </div>
#    </li>
#    <li>
#     <div>
#      Tobacco use - nicotine free for 4 weeks before and after
#     </div>
#    </li>
#    <li>
#     <div>
#      CT if needed
#     </div>
#    </li>
#    <li>
#     <div>
#      Note rectus diastasis, hernias, excess fat/skin, skin tone/appearance, scars
#     </div>
#    </li>
#    <li>
#     <div>
#      Diver's test
#     </div>
#    </li>
#    <li>
#     <div>
#      Pinch test
#     </div>
#    </li>
#    <li>
#     <div>
#      Have patient do a sit up
#     </div>
#    </li>
#    <li>
#     <div>
#      Patient expectations
#     </div>
#    </li>
#    <li>
#     <div>
#      Risk factors - esp for DVT/PE
#     </div>
#    </li>
#    <li>
#     <div>
#      If BMI &gt; 30, greater risk for wound complications and seromas
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Ppx antibiotics
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      No good evidence on duration
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     DVT ppx
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Consider MAC
#     </div>
#    </li>
#    <li>
#     <div>
#      Use SCDs
#     </div>
#    </li>
#    <li>
#     <div>
#      Caprini score for risk assessment
#     </div>
#    </li>
#    <li>
#     <div>
#      Consider chemoppx on case by case basis if Caprini &gt; 8
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Can be inpatient or outpatient
#    </div>
#   </li>
#   <li>
#    <div>
#     Anesthesia and analgesia
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Local anesthesia at surgical site is helpful
#     </div>
#    </li>
#    <li>
#     <div>
#      Use a variety of meds with different mechanisms of action
#     </div>
#    </li>
#    <li>
#     <div>
#      Liposomal bupivicaine (exparel)
#     </div>
#    </li>
#    <li>
#     <div>
#      TAP block - between IO and TA
#     </div>
#    </li>
#    <li>
#     <div>
#      Rectus sheath block - between RA and poster rectus sheath or transversalis fascia
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Markings
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Lower excision at least 5-7 cm above vulvar commissure and below any C-section scar
#     </div>
#    </li>
#    <li>
#     <div>
#      Upper incision made based on pinch test, inferior to ASIS
#     </div>
#    </li>
#    <li>
#     <div>
#      Check table and make sure it can flex
#     </div>
#    </li>
#    <li>
#     <div>
#      Compression stockings
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Operative technique
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Traditional abdominoplasty
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Umbilicus transposed
#      </div>
#     </li>
#     <li>
#      <div>
#       Rectus muscles plicated
#      </div>
#     </li>
#     <li>
#      <div>
#       Dissection carried to rectus sheath
#      </div>
#     </li>
#     <li>
#      <div>
#       Lower incision first, dissect up to xiphoid
#      </div>
#     </li>
#     <ul>
#      <li>
#       <div>
#        Transverse lower abdominal incision
#       </div>
#      </li>
#     </ul>
#     <li>
#      <div>
#       Minimize lateral dissection to preserve blood supply
#      </div>
#     </li>
#     <ul>
#      <li>
#       <div>
#        Wide undermining to costal margins
#       </div>
#      </li>
#     </ul>
#     <li>
#      <div>
#       Methylene blue to mark medial edge of rectus bilaterally
#      </div>
#     </li>
#     <li>
#      <div>
#       Plicate rectus
#      </div>
#     </li>
#     <ul>
#      <li>
#       <div>
#        Rectus sheath plication and diastasis repair
#       </div>
#      </li>
#      <ul>
#       <li>
#        <div>
#         Can be vertical or horizontal plication
#        </div>
#       </li>
#       <li>
#        <div>
#         Horizontal plication - observe the patient when flexed 90 degrees at the hips
#        </div>
#       </li>
#       <li>
#        <div>
#         Think about patient’s pulmonary status
#        </div>
#       </li>
#      </ul>
#     </ul>
#     <li>
#      <img src="resources/a7c71900a0c17614145cf72cb7ef367d.png"/>
#     </li>
#     <li>
#      <div>
#       Bed flexed
#      </div>
#     </li>
#     <li>
#      <div>
#       Excise skin/fat
#      </div>
#     </li>
#     <ul>
#      <li>
#       <div>
#        Resection of redundant abdominal flap with maximum resection centrally
#       </div>
#      </li>
#     </ul>
#     <li>
#      <div>
#       Close
#      </div>
#     </li>
#     <li>
#      <div>
#       Progressive tension sutures as flap is advanced to minimize dead space
#      </div>
#     </li>
#     <ul>
#      <li>
#       <div>
#        Progressive tension sutures results in fewer seromas but more scar revisions
#       </div>
#      </li>
#     </ul>
#     <li>
#      <div>
#       Inset umbilicus
#      </div>
#     </li>
#     <li>
#      <div>
#       Can +/- liposuction
#      </div>
#     </li>
#    </ul>
#   </ul>
#  </ul>
#  <img src="resources/f606a594cbf16b873d12662f98560ca1.png"/>
#  <img src="resources/39b3fad5caeb34d57c093985ab4853df.png"/>
#  <div>
#   <br/>
#  </div>
#  <ul>
#   <ul>
#    <li>
#     <div>
#      Mini-abdominoplasty
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Don't dissect above umbilicus
#      </div>
#     </li>
#     <li>
#      <div>
#       Umbilicus does not move
#      </div>
#     </li>
#     <li>
#      <div>
#       No rectus plication
#      </div>
#     </li>
#     <li>
#      <div>
#       Just removing excess skin/fat below umbilicus
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      High lateral tension (Lockwood)
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Oblique vector of pull of abdominal skin flap
#      </div>
#     </li>
#     <li>
#      <div>
#       Reduces horizontal epigastric laxity
#      </div>
#     </li>
#     <li>
#      <div>
#       More skin is excised laterally than centrally
#      </div>
#     </li>
#     <li>
#      <div>
#       Tension at line of closure is held by Scarpa's fascia
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Fleur de lis
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Includes excision of vertical ellipse
#      </div>
#     </li>
#     <li>
#      <div>
#       For patients with both horizontal and vertical skin excess like MWL patient
#      </div>
#     </li>
#     <li>
#      <div>
#       Additional scar
#      </div>
#     </li>
#    </ul>
#    <li>
#     <img src="resources/88099ba5f3aa6774a2d5c77133238b1d.png"/>
#    </li>
#    <li>
#     <div>
#      Lipo-abdominoplasty
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Liposuction of abdominal skin flap rather than wide lateral undermining to preserve blood supply
#      </div>
#     </li>
#    </ul>
#   </ul>
#   <li>
#    <div>
#     Post-op care
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Patient is flexed at waist
#     </div>
#    </li>
#    <li>
#     <div>
#      Beach chair position of bed
#     </div>
#    </li>
#    <li>
#     <div>
#      Even when ambulating, stay flexed at waist
#     </div>
#    </li>
#    <li>
#     <div>
#      Compression garment
#     </div>
#    </li>
#    <li>
#     <div>
#      Risk of VTE--get patients walking early!
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Scar care
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Minimize tension
#     </div>
#    </li>
#    <li>
#     <div>
#      Prineo has similar outcomes and is faster to perform
#     </div>
#    </li>
#    <li>
#     <div>
#      Pressure garments, scar massage
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Complications
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Dog ears
#     </div>
#    </li>
#    <li>
#     <div>
#      Wound deshicence
#     </div>
#    </li>
#    <li>
#     <div>
#      Wide scars
#     </div>
#    </li>
#    <li>
#     <div>
#      Seroma
#     </div>
#    </li>
#    <li>
#     <div>
#      Flap ischemia
#     </div>
#    </li>
#    <li>
#     <div>
#      VTE/PE - do risk assessment
#     </div>
#    </li>
#    <li>
#     <div>
#      Nerve injuries
#     </div>
#    </li>
#    <li>
#     <div>
#      Obesity related complications
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Post op outcomes
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Seroma reduction with tissue adhesives
#     </div>
#    </li>
#    <li>
#     <div>
#      Scars - silicone gel sheets, paper tape, lasers, massage
#     </div>
#    </li>
#    <li>
#     <div>
#      Cutaneous sensibility - transient hypesthesia
#     </div>
#    </li>
#    <li>
#     <div>
#      Weight loss
#     </div>
#    </li>
#    <li>
#     <div>
#      Urinary incontinence improvement
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Combined with other procedures
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Liposuction
#     </div>
#    </li>
#    <li>
#     <div>
#      Breast aug
#     </div>
#    </li>
#    <li>
#     <div>
#      Complications: hematoma, infection, DVT
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <div>
#   <br/>
#  </div>
#  <img src="resources/a44e7a7f85ae5beb6eb7b7d3942ffada.bin"/>
#  <div>
#   <br/>
#  </div>
#  <img src="resources/1fb1141589b3c98e327622d637d282ce.bin"/>
#  <div>
#   <br/>
#  </div>
#  <div>
#   <br/>
#  </div>
#  <div>
#   Belt Lipectomy
#  </div>
#  <ul>
#   <li>
#    <div>
#     After MWL, circumferential abdominal treatment
#    </div>
#   </li>
#   <li>
#    <div>
#     Anatomy
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Huger Zones
#     </div>
#    </li>
#    <li>
#     <div>
#      Abdominal wall anatomy
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Patient selection and evaluation
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Expectations
#     </div>
#    </li>
#    <li>
#     <div>
#      Method of weight loss, should be stable for at least 3-6 months prior to surgery, wait at least 12-18 months after bariatric surgery
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Within 10-15% of goal body weight
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Nutrition
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Daily protein intake: 60-100g
#      </div>
#     </li>
#     <ul>
#      <li>
#       <div>
#        Bariatric patients: 60-70g perioperatively
#       </div>
#      </li>
#     </ul>
#     <li>
#      <div>
#       Iron
#      </div>
#     </li>
#     <li>
#      <div>
#       Vitamin C
#      </div>
#     </li>
#     <li>
#      <div>
#       Vitamin B12, B6, B1
#      </div>
#     </li>
#     <li>
#      <div>
#       Vitamin A
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      VTE risk factors
#     </div>
#    </li>
#    <li>
#     <div>
#      Skin quality - rash, intertrigo, striae, previous incisions, thickness, excess
#     </div>
#    </li>
#    <li>
#     <div>
#      CT scan if needed
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Markings
#    </div>
#   </li>
#   <ul>
#    <li>
#     <img src="resources/6a029d26eb182f5e96665e22de58d068.png"/>
#    </li>
#    <li>
#     <div>
#      In pic above, green indicates eventual scar location
#     </div>
#    </li>
#    <li>
#     <div>
#      ASIS, PSIS, iliac crests are marked
#     </div>
#    </li>
#    <li>
#     <div>
#      Upper and lower incisions similar to abdominoplasty however they go circumferentially
#     </div>
#    </li>
#    <li>
#     <div>
#      Posteriorly, you have narrow resection width
#     </div>
#    </li>
#    <li>
#     <div>
#      Use pinch test to guide markings
#     </div>
#    </li>
#    <li>
#     <div>
#      Closure is at or above ASIS so scar can be hidden
#     </div>
#    </li>
#    <li>
#     <div>
#      <b>
#       Note that the incisions for belt lipectomy are higher than those for lower body lift
#      </b>
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Technique
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Position changes anticipated
#     </div>
#    </li>
#    <li>
#     <div>
#      Usual abdominoplasty technique carried out first, except more lateral undermining is done
#     </div>
#    </li>
#    <li>
#     <div>
#      Repair rectus diastasis
#     </div>
#    </li>
#    <li>
#     <div>
#      Redrape abdominal flap and place prgressive tension sutures
#     </div>
#    </li>
#    <li>
#     <div>
#      Close anterior abdomen, lateral aspects are closed with staples provisionally and patient is repositioned prone or lateral decub
#     </div>
#    </li>
#    <li>
#     <div>
#      Posterior incisions are made based on tailor tacking and cut as you go techniques, dissection carried down to musculofascia
#     </div>
#    </li>
#    <li>
#     <div>
#      Little to no undermining of superior/inferior skin flaps on the back is done
#     </div>
#    </li>
#    <li>
#     <div>
#      To optimize superior excursion of lateral thigh and minimize contour irregularities, liposuction discontinuously to disrupt pelvic rim zone of adherence
#     </div>
#    </li>
#    <li>
#     <div>
#      Reposition to supine beach chair
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Complications
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      VTE/PE
#     </div>
#    </li>
#    <li>
#     <div>
#      Overresection
#     </div>
#    </li>
#    <li>
#     <div>
#      Wound healing problems
#     </div>
#    </li>
#    <li>
#     <div>
#      Wound dehiscence
#     </div>
#    </li>
#    <li>
#     <div>
#      Seroma
#     </div>
#    </li>
#    <li>
#     <div>
#      Hematoma
#     </div>
#    </li>
#    <li>
#     <div>
#      Flap necrosis
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Drainless abdominoplasty  - Brannon Claytor
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      To get "snatched" look, lipo up along lateral chest wall along breast and go down
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Do not go under ribs and perf pleura
#      </div>
#     </li>
#     <li>
#      <div>
#       Go up to down and be aggressive about lipo the medial flap as well
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      It's not just removing loose skin but tightening rectus fascia
#     </div>
#    </li>
#    <li>
#     <div>
#      Cut out belly button first, take out specimen en bloc
#     </div>
#    </li>
#    <li>
#     <div>
#      Lymphatic massage post op can help with edema, don't think it's a seroma
#     </div>
#    </li>
#    <li>
#     <div>
#      You can notice that with the lower skin flap, if you grab and pull it up you can improve some lateral and medial thigh cellulite
#     </div>
#    </li>
#    <li>
#     <div>
#      Not just progressive tension sutures
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/b1db70d5ac2baef87824ff5f9605df70.png"/>
#  <ul style="--en-todo:true;">
#   <ul>
#    <li>
#     <div>
#      Abdominal binder -- mark how tight you put it on, skin glue, ambulate POD1
#     </div>
#    </li>
#    <li>
#     <div>
#      Marking abdominal binder is important so patient can adhere at home
#     </div>
#    </li>
#    <li>
#     <div>
#      Permanent sutures for rectus diastasis rather than PDS - monofilament rather than braided, use a prolene
#     </div>
#    </li>
#    <li>
#     <div>
#      Three layers - interrupted, running, and then one more running absorbable layer
#     </div>
#    </li>
#    <li>
#     <div>
#      Progressive tension sutures - absorbable
#     </div>
#    </li>
#    <li>
#     <div>
#      Needle aid in centering incisions, put a 20g needle through center of flap
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       V-shape incision on skin flap for umbilicus inset
#      </div>
#     </li>
#     <li>
#      <div>
#       Defat the belly button
#      </div>
#     </li>
#     <li>
#      <div>
#       Permanent suture at top of BB, everything else absorbable
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      When you cut across lymphatics in abdomen, it's low pressure, and if you force the body fluid to go elsewhere the channels will close and go elsewhere; if you put a drain in, the lymph channels stent open there's no pressure to close
#     </div>
#    </li>
#    <li>
#     <div>
#      Minimum 3 L tumescent
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/5baa51439e5d0aeffa6d4196652414ab.png"/>
#  <ul style="--en-todo:true;">
#   <ul>
#    <li>
#     <div>
#      Preservation of Scarpa's fascia infraumbilically
#     </div>
#    </li>
#    <li>
#     <div>
#      Reduced drain output by 50% and duration fo drain by 2 days
#     </div>
#    </li>
#    <li>
#     <div>
#      Many lymphatics live in Scarpa's fascia beyond the dermis
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/3c6fa7762448b5bf75eac894f1aca25b.png"/>
#  <ul>
#   <li>
#    <div>
#     Uses cut on cautery or knife, rarely uses coag
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Reduce thermal trauma
#     </div>
#    </li>
#    <li>
#     <div>
#      Save perforators so you have good vascular supply, liposuction the flap is in fact okay
#     </div>
#    </li>
#    <li>
#     <div>
#      Since Scarpa's is preserved, you can lift the thigh tissue up with the fascia and it helps with the thighs and overall asethetic results
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Drainless abdominoplasty - Karol Gutowski
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      4-5L tumescent in trunk
#     </div>
#    </li>
#    <li>
#     <div>
#      360 lipo and abdominoplasty
#     </div>
#    </li>
#    <li>
#     <div>
#      Do not put scar more than 6cm above vaginal opening, keep the scar LOW because it stretches and rides up
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/d757abdd3672a7516f0111f5b6a7915c.png"/>
#  <img src="resources/79d615a0865d4cee45ad610f98cd1b4e.png"/>
#  <ul style="--en-todo:true;">
#   <ul>
#    <li>
#     <div>
#      Tell patients it will be a long scar
#     </div>
#    </li>
#    <li>
#     <div>
#      Mons lipo so they will swell up
#     </div>
#    </li>
#    <li>
#     <div>
#      Progressive tension sutures !!
#     </div>
#    </li>
#    <li>
#     <div>
#      Really the only procedure he puts drains in for are vertical thigh lifts
#     </div>
#    </li>
#    <li>
#     <div>
#      <b>
#       Absorbable barbed sutures for progressive tension sutures !!!
#      </b>
#     </div>
#    </li>
#    <li>
#     <div>
#      <b>
#       <span style="--en-markholder:true;">
#        <br/>
#       </span>
#      </b>
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/9008387184e37ee1a6385d238b68b21b.png"/>
#  <img src="resources/b78f90497f3a9c98851bbb502bcf7d83.png"/>
#  <img src="resources/ea2e627b69b3f09b2334f02c359d9900.png"/>
#  <img src="resources/fb1c56d730a01aa0173c66eab769734b.png"/>
#  <img src="resources/60a2cb84c4f4aa9b9c1d4faac7051248.png"/>
#  <div>
#   <br/>
#  </div>
#  <ul style="--en-todo:true;">
#   <ul>
#    <li>
#     <div>
#      PTS technique
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Use your non-dominant hand to pull the flap down and get that "progressive tension" by pulling flap down
#      </div>
#     </li>
#     <li>
#      <div>
#       Put stitches to secure in place
#      </div>
#     </li>
#     <li>
#      <div>
#       Many needles in the field, sometimes 4-6 in the  field
#      </div>
#     </li>
#     <li>
#      <div>
#       Mark suture track so resident knows where sutures go and avoid tendency to pull flap in the wrong direction
#      </div>
#     </li>
#     <li>
#      <div>
#       Mark abdominal lines, take flap down and press it, then the markings appear on anterior flap
#      </div>
#     </li>
#     <li>
#      <div>
#       You have guidelines on both sides
#      </div>
#     </li>
#    </ul>
#   </ul>
#  </ul>
#  <img src="resources/b1c26f7fa70fba730d3ece1e99c1f946.png"/>
#  <ul>
#   <li>
#    <div>
#     Leave some fat down on ab wall so that it can absorb the lymphatics
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      No ab binder, foam and high quality compression garment to avoid binders from being too loose or sliding up
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Mesh
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Absorbable PDO mesh
#     </div>
#    </li>
#    <li>
#     <div>
#      Inset with PDS
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Rectus plication
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Does not use permanent suture
#     </div>
#    </li>
#    <li>
#     <div>
#      Recommends monofilament nonabsorbable sutures if necessary
#     </div>
#    </li>
#    <li>
#     <div>
#      Interrupted vicryl
#     </div>
#    </li>
#    <li>
#     <div>
#      Barbed absorbable 0 or 2-0 PDO
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/8e2d955a82c4c366430324bdeb5a3b6d.png"/>
#  <ul>
#   <li>
#    <div>
#     US in office for analysis
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Minor thin layers of fluid are normal
#     </div>
#    </li>
#    <li>
#     <div>
#      Aspirate if in doubt
#     </div>
#    </li>
#    <li>
#     <div>
#      SeromaCath
#     </div>
#    </li>
#    <li>
#     <div>
#      Sclerosis - doxycycline, ethanol
#     </div>
#    </li>
#    <li>
#     <div>
#      Excision
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Lymphatic drainage massage after liposuction and aesthetic surgery
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Very little data on it
#     </div>
#    </li>
#    <li>
#     <div>
#      Frequently done
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Drainless abdominoplasty - Larry Iteld
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      How to transition from drain to drainless
#     </div>
#    </li>
#    <li>
#     <div>
#      PTS - decrease dead space, offload tension, decrease shear forces, decrease risk of scar migration
#     </div>
#    </li>
#    <li>
#     <div>
#      The longer you keep a drain in, the higher risk of seroma
#     </div>
#    </li>
#    <li>
#     <div>
#      You can lipo the flap but you have to preserve lateral row perforators
#     </div>
#    </li>
#    <li>
#     <div>
#      Low incision, horizontal in pubis, as everything rides it up it levels out
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/d5b5307fc312c8b85c473282db8aa793.png"/>
#  <ul style="--en-todo:true;">
#   <ul>
#    <li>
#     <div>
#      Tumesce first
#     </div>
#    </li>
#    <li>
#     <div>
#      When doing lipo, leave some fat along midline because when you put PTS in you may get dimpling
#     </div>
#    </li>
#    <li>
#     <div>
#      Elevate flap, in supra mons area, bevel and leave some tissue down, because if you over liposuction it's in supraumbilical segment so you have a buffer and it won't "dip" down
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       At the end, if you want more lipo in mons area you can do it
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Split flap and use facelift scissors around umbilical stalk
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       Push down and evert umbilical stalk, mark as deep as you can
#      </div>
#     </li>
#     <li>
#      <div>
#       By doing that you don't make umbilical circumference too small
#      </div>
#     </li>
#    </ul>
#    <li>
#     <div>
#      Go around skin of umbilicus with facelift scissors, avoid thermal injury
#     </div>
#    </li>
#    <li>
#     <div>
#      Once you know you're good, continue elevation narrowly, preserve lateral row perforators, superior flap has been discontinuously undermined with liposuction
#     </div>
#    </li>
#    <li>
#     <div>
#      When doing plication he does hash marks across rectus plication, this prevents grabbing too much tissue on each side
#     </div>
#    </li>
#    <li>
#     <div>
#      Uses 0 loop PDS that he runs, uses two of them
#     </div>
#    </li>
#    <ul>
#     <li>
#      <div>
#       One from xiphoid to umbilicus
#      </div>
#     </li>
#     <li>
#      <div>
#       One from umbilicus to pubis
#      </div>
#     </li>
#     <li>
#      <div>
#       LOCKS IT
#      </div>
#     </li>
#    </ul>
#   </ul>
#  </ul>
#  <img src="resources/c5313b20268d5c9fe393834325bf0b97.png"/>
#  <ul>
#   <li>
#    <div>
#     PTS with stratafix - barbed suture
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Doesn't loosen and additional friction doesn't tear through
#     </div>
#    </li>
#    <li>
#     <div>
#      Does one handed as a mattress suture
#     </div>
#    </li>
#    <li>
#     <div>
#      Forehand on upper flap, backhand against fascia
#     </div>
#    </li>
#    <li>
#     <div>
#      Running suture to umbilicus
#     </div>
#    </li>
#    <li>
#     <div>
#      Use thumb to advance flap down to where you want to go
#     </div>
#    </li>
#    <li>
#     <div>
#      When you start your suture on abdominal fascia, start 2-3 cm below xiphoid, reach back up as high as you can
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <img src="resources/6974d5ac05033612d458a15a8bfe2509.png"/>
#  <ul>
#   <li>
#    <div>
#     Stabilize umbilical stalk at four points in muscle
#    </div>
#   </li>
#   <li>
#    <div>
#     Mark undersurface of flap, tells you where to go
#    </div>
#   </li>
#   <li>
#    <div>
#     Umbilical inset
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Key is to use it as a tension point
#     </div>
#    </li>
#    <li>
#     <div>
#      Nothing fancy
#     </div>
#    </li>
#    <li>
#     <div>
#      Create indentation by tacking native umbilicus down and shortening stalk, conservatively defat area, when sewing opening in, it pulls it downward which gives you the look of a umbilicus
#     </div>
#    </li>
#    <li>
#     <div>
#      How do you mark it?
#     </div>
#    </li>
#    <li>
#     <div>
#      Put finger underneath, feel where it is, mark umbilicus 1-cm above that point, so 1-2cm above its natural laying
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Lower PTS
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Running suture supra-umbilical
#     </div>
#    </li>
#    <li>
#     <div>
#      Infra-umbilical interrupted !
#     </div>
#    </li>
#    <li>
#     <div>
#      Midline first, then paramedian, vicryl
#     </div>
#    </li>
#   </ul>
#   <li>
#    <div>
#     Post op
#    </div>
#   </li>
#   <ul>
#    <li>
#     <div>
#      Sees everyone POD1
#     </div>
#    </li>
#    <li>
#     <div>
#      Topifoam, garments, manual lymphatic drainage
#     </div>
#    </li>
#   </ul>
#  </ul>
#  <div>
#   <br/>
#  </div>
# </en-note>

# %%
#This is the clean content for the OpenAI model

#Clean parsed note content
note_content = cleaned_content  

#Pull in the prompt
with open("system_prompt.txt", "r") as f:
    system_msg = f.read()

#Make the call 
response = client.chat.completions.create(
    model="gpt-5",
    messages=[
        {"role": "system", "content": system_msg},
        {"role": "user", "content": note_content}
    ]
    #temperature=0 #GPT-5 models don't support temperature setting  
)

markdown_output = response.choices[0].message.content

#Final note combines YAML metadata and cleaned markdown content
final_note = f"{yaml_metadata}\n\n{markdown_output}"

#Save to file
with open("cleaned_note.md", "w", encoding="utf-8") as f:
    f.write(final_note)
